# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramlakhan-123/workshop1/blob/main/Ram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
print(a)
# Out:
# 3

# %%
b=5
print(b)
# Out:
# 5

# %%
students= {
    "name":"ram",
    "class":"2nd year",
    "roll":133
}
print(students)
# Out:
# {'name': 'ram', 'class': '2nd year', 'roll': 133}

# %%
marks=50
if(marks>=30):
  print("pass")
else:
  print("fail")
# Out:
# pass

# %%
marks=[2,3,4,5]
for i in marks:
  print(i,end=" ")
# Out:
# 2 3 4 5

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
total=0
marks=[70,80,90,100]
for m in marks:
  total=total+m
print(total)
# Out:
# 340

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30

# %%
import numpy as np
arr=np.array([1,2,3,4])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
my_list=[1,2,3,4]
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
import numpy as np
arr=np.array([[1,2,3],
              [4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2 = np.array([[1, 2, 3],
                 [4, 5, 6]])
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
arr=np.array([1,2,3,4])
print(arr +5)
# Out:
# [6 7 8 9]

# %%
arr=np.array([1,2,3,4])
print(np.mean(arr))
# Out:
# 2.5

# %%
import pandas as pd
data= {
    "name":["ram","shyam","shivam"],
    "roll":[12,13,14],
    "section":['A','B','C']
}
df = pd.DataFrame(data)
print(df)
# Out:
#      name  roll section
# 0     ram    12       A
# 1   shyam    13       B
# 2  shivam    14       C

# %%
print(df.head())
# Out:
#      name  roll section
# 0     ram    12       A
# 1   shyam    13       B
# 2  shivam    14       C

# %%
print(df.tail())
# Out:
#      name  roll section
# 0     ram    12       A
# 1   shyam    13       B
# 2  shivam    14       C

# %%
print(df.shape)
# Out:
# (3, 3)

# %%
print(df.columns)
# Out:
# Index(['name', 'roll', 'section'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     3 non-null      object
#  1   roll     3 non-null      int64
#  2   section  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        roll
# count   3.0
# mean   13.0
# std     1.0
# min    12.0
# 25%    12.5
# 50%    13.0
# 75%    13.5
# max    14.0

# %%
print(df["name"])
print(df["roll"])
# Out:
# 0       ram
# 1     shyam
# 2    shivam
# Name: name, dtype: object
# 0    12
# 1    13
# 2    14
# Name: roll, dtype: int64

# %%
print(df[["name","roll"]])
# Out:
#      name  roll
# 0     ram    12
# 1   shyam    13
# 2  shivam    14

# %%
print(df[df["roll"]==12])
# Out:
#   name  roll section
# 0  ram    12       A

# %%
with open("/content/sample_data/file1",'w') as f:
    f.write("my first file\n")
    f.write("how are you\n")
